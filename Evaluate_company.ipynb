# %% [markdown]
# # This notebook is for evaluating a specific company
# ## We want to determine if their stock is under- or overvalued

# %%
import pandas as pd
import numpy as np
import datetime as dt
from functions import monitor_stock
import yfinance as yf
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# example_ticker = "TSLA"
example_ticker = "MSFT"


ticker_obj = yf.Ticker(example_ticker)

# %%
monitor_stock(example_ticker)

# %%
cashflows = ticker_obj.quarterly_cashflow
financials = ticker_obj.quarterly_financials
balance = ticker_obj.quarterly_balance_sheet
earnings = ticker_obj.quarterly_earnings.transpose().astype(np.float64)
earnings.columns = balance.columns
key_df = pd.concat([earnings,cashflows,financials,balance])
sorted(key_df.index.tolist())
# Out:
# ['Accounts Payable',
#  'Capital Expenditures',
#  'Cash',
#  'Change In Cash',
#  'Change To Account Receivables',
#  'Change To Inventory',
#  'Change To Liabilities',
#  'Change To Netincome',
#  'Change To Operating Activities',
#  'Common Stock',
#  'Cost Of Revenue',
#  'Deferred Long Term Asset Charges',
#  'Depreciation',
#  'Discontinued Operations',
#  'Dividends Paid',
#  'Earnings',
#  'Ebit',
#  'Effect Of Accounting Charges',
#  'Effect Of Exchange Rate',
#  'Extraordinary Items',
#  'Good Will',
#  'Gross Profit',
#  'Income Before Tax',
#  'Income Tax Expense',
#  'Intangible Assets',
#  'Interest Expense',
#  'Inventory',
#  'Investments',
#  'Issuance Of Stock',
#  'Long Term Debt',
#  'Long Term Investments',
#  'Minority Interest',
#  'Net Borrowings',
#  'Net Income',
#  'Net Income',
#  'Net Income Applicable To Common Shares',
#  'Net Income From Continuing Ops',
#  'Net Receivables',
#  'Net Tangible Assets',
#  'Non Recurring',
#  'Operating Income',
# ...

# %%
earnings
# Out:
#             2021-03-31    2020-12-31    2020-09-30    2020-06-30
# Revenue   3.803300e+10  3.715400e+10  4.307600e+10  4.170600e+10
# Earnings  1.120200e+10  1.389300e+10  1.546300e+10  1.545700e+10

# %% [markdown]
# Calculated these by hand; plot their corresponding quarterly development:
# Earnings per share (EPS) -->   Net Income Applicable To Common Shares / Common Stock
# Price-to-Book ratio (P/B) -->
# Price-earnings ratio () --> Share price / EPS
# Price-sales ratio () -->
# Profit margin ratio () --> Net Income / Revenue
# Dividend payout ratio () -->
# Price-free cash flow ratio () -->
# Debt-equity ratio () -->
# Quick and current ratios () -->
# EBITDA-to-sales ratio () -->

# %%
key_df.loc["Net Income"]/key_df.loc["Common Stock"]
# Out:
#            2021-03-31 2020-12-31 2020-09-30 2020-06-30
# Net Income   0.187795   0.188813    0.17133   0.139065
# Net Income   0.187795   0.188813    0.17133   0.139065

# %%
ticker_obj.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2020-08-31        0.0           5.0
